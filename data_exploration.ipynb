# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/vinee/OneDrive/Desktop/projects/Causal_Inference/synthetic_population.csv")

# %%
# lets breakdown the structure of the dataset
df.describe()
# Out:
#                  id          age   county_code  household_id  household_size  \
# count  50000.000000  50000.00000  50000.000000  50000.000000    50000.000000
# mean   25000.500000     36.86210   6360.048920  11529.460800        2.638320
# std    14433.901067     22.16797    444.975725   6666.078744        1.060175
# min        1.000000      0.00000   6001.000000      1.000000        1.000000
# 25%    12500.750000     16.00000   6037.000000   5740.750000        2.000000
# 50%    25000.500000     38.00000   6071.000000  11538.500000        3.000000
# 75%    37500.250000     52.00000   6999.000000  17272.000000        3.000000
# max    50000.000000     90.00000   6999.000000  23096.000000        5.000000
#
#        multigenerational  frontline_worker  ses_quintile
# count       50000.000000      50000.000000  50000.000000
# mean            0.113660          0.331560      2.896520
# std             0.317401          0.470779      1.425557
# ...

# %%
# plotting the distribution of age
plt.figure(figsize=(10,6))
plt.hist(df["age"], bins=20, edgecolor = 'black')
plt.title("Age Distribution")
plt.xlabel("age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(df['age'], fill=True)
plt.title("Age Distribution (KDE)")
plt.xlabel("Age")
plt.ylabel("Density")
plt.show()

# %%
((df["has_obesity"]) & (df["has_hypertension"])).sum()
# Out:
# np.int64(3312)

# %%
df['frontline_worker'].sum()
# Out:
# np.int64(16578)

# %%
df[df["household_size"] == 5]
# Out:
#           id  age       county  county_code  household_id  household_size  \
# 250      251   33  Santa Clara         6085           113               5
# 251      252   34  Santa Clara         6085           113               5
# 252      253   11  Santa Clara         6085           113               5
# 253      254   12  Santa Clara         6085           113               5
# 254      255    6  Santa Clara         6085           113               5
# ...      ...  ...          ...          ...           ...             ...
# 49763  49764   43  Los Angeles         6037         22978               5
# 49764  49765   30  Los Angeles         6037         22978               5
# 49765  49766   15  Los Angeles         6037         22978               5
# 49766  49767    7  Los Angeles         6037         22978               5
# 49767  49768   12  Los Angeles         6037         22978               5
#
#               household_type  multigenerational      occupation  \
# ...
